# %%
import pandas as pd
import os 
import numpy as np
from pyranges import PyRanges
import pairtools
import pairtools.lib.headerops as phead

# %%
def load_pairs(fpath, comment_char="#"):
    """Loads a pairs table from a tab-separated file.

    Args:
        fpath (str): The file path to the pairs table.
        comment_char (str, optional): The character indicating comment lines. 
                                     Defaults to "#".

    Returns:
        pd.DataFrame: A Pandas DataFrame containing the pairs table data.
    """
    header = phead.get_header(open(fpath))[0][-1]
    header = header.replace("#columns: ", "")
    header = header.split(" ")
    
    df = pd.read_csv(fpath, 
                     sep='\t', 
                     header=None, 
                     names=header, 
                     comment="#")
    return df


fpath = '/scratch/indikar_root/indikar1/shared_data/single_cell/expanded/pairs/o1b05.GRCm39.expanded.pairs'
df = load_pairs(fpath)
print(f"{df.shape=}")
df.head()
# Out:
# df.shape=(1353139, 24)
#                                  readID chrom1       pos1 chrom2       pos2  \
# 0  c984758d-b12e-44a0-86fa-f5bb326837f1      !          0      4   42850159
# 1  6b11c966-4911-4640-a640-c3b651524b5b      !          0      1  160219378
# 2  6b11c966-4911-4640-a640-c3b651524b5b      !          0      1  160218505
# 3  6b11c966-4911-4640-a640-c3b651524b5b      1  160218789      1  160218505
# 4  8f835bd9-c2ce-4dbd-8784-11672532138c      !          0     11   72720934
#
#   strand1 strand2 pair_type  mapq1  mapq2  ...  algn_ref_span1  \
# 0       -       +        NU      0      1  ...               0
# 1       -       +        NU      0     60  ...               0
# 2       -       -        NU      0     60  ...               0
# 3       +       -        UU     60     60  ...             590
# 4       -       +        NU      0     21  ...               0
#
#    algn_ref_span2  matched_bp1  matched_bp2  rfrag1  rfrag_start1  rfrag_end1  \
# 0             243            0          242      -1             0           0
# 1             590            0          589      -1             0           0
# 2             278            0          276      -1             0           0
# 3             278          589          276  760124     160218511   160218791
# 4              61            0           61      -1             0           0
#
#    rfrag2  rfrag_start2  rfrag_end2
# 0  183807      42849815    42850205
# 1  760125     160218791   160219386
# 2  760123     160218281   160218511
# 3  760123     160218281   160218511
# 4  345258      72720876    72720976
#
# [5 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['readID', 'chrom1', 'pos1', 'chrom2', 'pos2', 'strand1', 'strand2',
#        'pair_type', 'mapq1', 'mapq2', 'read_len1', 'read_len2',
#        'algn_read_span1', 'algn_read_span2', 'algn_ref_span1',
#        'algn_ref_span2', 'matched_bp1', 'matched_bp2', 'rfrag1',
#        'rfrag_start1', 'rfrag_end1', 'rfrag2', 'rfrag_start2', 'rfrag_end2'],
#       dtype='object')

# %%
def filter_unmapped(df):
    """A function to filter the unmapped reads """
    df = df[(df['chrom1'] != "!") & (df['chrom2'] != "!")].copy()
    return df

def filter_adjacent(df, tolerance=1):
    """A function to filter out fragments
    adjacent on the reference """
    return df[df['rfrag1'].sub(df['rfrag1'].shift(1)).abs() > tolerance].copy()

def filter_close_contact(df, bp=1000):
    """A function to filter contacts which are close"""
    return df[~((df['chrom1'] == df['chrom2']) & (df['pos1'].sub(df['pos2']).abs() < bp))].copy()


def filter_duplicate_contacts(df):
    return (df.assign(rfrag_diff=df['rfrag1'].sub(df['rfrag2']).abs())
              .sort_values('rfrag_diff')
              .drop_duplicates(subset=['rfrag1', 'rfrag2'], keep='first')
              .drop(columns=['rfrag_diff']))


def filter_promiscuous_fragments(df, threshold = 10):
    """Filters out contacts involving promiscuous fragments from a DataFrame.

    Args:
        df (pd.DataFrame): DataFrame containing contact information with 'rfrag1' and 'rfrag2' columns.
        threshold (int, optional): The minimum number of interactions for a fragment to be considered promiscuous. Defaults to 10.

    Returns:
        pd.DataFrame: The filtered DataFrame with contacts involving promiscuous fragments removed.
    """

    fragment_counts = (pd.concat([df["rfrag1"], df["rfrag2"]])
                         .value_counts()
                         .reset_index(name="freq")
                         .rename(columns={"index": "fragment_id"}))

    promiscuous_fragments = fragment_counts[fragment_counts["freq"] > threshold]["fragment_id"].tolist()

    return df[~(df["rfrag1"].isin(promiscuous_fragments) | df["rfrag2"].isin(promiscuous_fragments))]


def filter_isolated_fragments(df, max_distance = 10_000_000):
    """Filters out contacts involving isolated fragments from a DataFrame.

    Args:
        df (pd.DataFrame): DataFrame containing contact information with 
            'rfrag1', 'rfrag2', 'chrom1', 'pos1', 'chrom2', 'pos2' columns.
        max_distance (int, optional): The maximum distance to another fragment for a fragment to be considered non-isolated. Defaults to 10,000,000.

    Returns:
        pd.DataFrame: The filtered DataFrame with contacts involving isolated fragments removed.
    """
    
    # Create a combined DataFrame with fragment information
    fragment_data = pd.concat([
        df[['rfrag1', 'chrom1', 'rfrag_start1', 'rfrag_end1']].rename(columns={'rfrag1': 'id', 'chrom1': 'Chromosome', 'rfrag_start1': 'Start', 'rfrag_end1': 'End'}),
        df[['rfrag2', 'chrom2', 'rfrag_start2', 'rfrag_end2']].rename(columns={'rfrag2': 'id', 'chrom2': 'Chromosome', 'rfrag_start2': 'Start', 'rfrag_end2': 'End'}),
    ]).drop_duplicates()

    # Create PyRanges object
    frag_ranges = PyRanges(fragment_data)

    # Find nearest neighbors
    nearest_fragments = frag_ranges.nearest(frag_ranges)

    # Identify isolated fragments
    isolated_fragments = nearest_fragments.df[nearest_fragments.df["Distance"] > max_distance]["id"].tolist()

    # Filter out contacts involving isolated fragments
    return df[~(df["rfrag1"].isin(isolated_fragments) | df["rfrag2"].isin(isolated_fragments))]


pdf = filter_unmapped(df)
print(f"{pdf.shape=}")

pdf = filter_adjacent(pdf)
print(f"{pdf.shape=}")

pdf = filter_close_contact(pdf)
print(f"{pdf.shape=}")

pdf = filter_duplicate_contacts(pdf)
print(f"{pdf.shape=}")

pdf = filter_promiscuous_fragments(pdf)
print(f"{pdf.shape=}")

pdf = filter_isolated_fragments(pdf)
print(f"{pdf.shape=}")
# Out:
# pdf.shape=(190905, 24)
# pdf.shape=(189740, 24)
# pdf.shape=(131727, 24)
# pdf.shape=(6479, 24)
# pdf.shape=(4207, 24)
# pdf.shape=(4207, 24)

# %%
def contact_filter(df):
    """Filters contacts, returning the filtered DataFrame and a summary of filter results.

    Args:
        df (pandas.DataFrame): DataFrame with contact information.

    Returns:
        tuple: A tuple containing:
            - pandas.DataFrame: The final filtered DataFrame.
            - pandas.DataFrame: A DataFrame summarizing the number of rows removed by each filter.
    """

    df = df.reset_index(drop=True).copy()  # Ensure a copy to avoid SettingWithCopyWarning
    summary_data = []

    filters = [
        (filter_unmapped, "unmapped"),
        (filter_adjacent, "adjacent"),
        (filter_close_contact, "close_contact"),
        (filter_duplicate_contacts, "duplicate"),
        (filter_promiscuous_fragments, "promiscuous"),
        (filter_isolated_fragments, "isolated"),
    ]

    for filter_func, filter_name in filters:
        original_size = len(df)
        df = filter_func(df)  # Apply the filter
        filtered_out_count = original_size - len(df) # Calculate rows removed
        summary_data.append({"filter": filter_name, "rows_filtered_out": filtered_out_count}) # Store summary

    summary_df = pd.DataFrame(summary_data)  # Create summary DataFrame
    return df, summary_df

pdf, sum_df = contact_filter(df)
pdf.shape
# Out:
# (4207, 24)

# %%
sum_df
# Out:
#           filter  rows_filtered_out
# 0       unmapped            1162234
# 1       adjacent               1165
# 2  close_contact              58013
# 3      duplicate             125248
# 4    promiscuous               2272
# 5       isolated                  0

# %%
def write_pairs(df, header, outpath):
    """A function to write a pairs file """
    with open(outpath, "a") as file:  # Open in append mode
        for line in header:
            file.write(line + "\n") 
        
    df.to_csv(outpath, mode='a', header=None, sep="\t", index=False)
    
    

fpath = '/scratch/indikar_root/indikar1/shared_data/single_cell/expanded/pairs/o1b05.GRCm39.expanded.pairs'
header = phead.get_header(open(fpath))[0]

outpath = "/home/cstansbu/temp/test.pairs"

write_pairs(df, header, outpath)

# %%
fpath = '/scratch/indikar_root/indikar1/shared_data/single_cell/expanded/pairs/o1b05.GRCm39.expanded.pairs'
phead.get_header(open(fpath))[0]
# Out:
# ['## pairs format v1.0.0',
#  '#shape: whole matrix',
#  '#genome_assembly: unknown',
#  '#chromsize: 1 195154279',
#  '#chromsize: 2 181755017',
#  '#chromsize: 3 159745316',
#  '#chromsize: 4 156860686',
#  '#chromsize: 5 151758149',
#  '#chromsize: 6 149588044',
#  '#chromsize: 7 144995196',
#  '#chromsize: 8 130127694',
#  '#chromsize: 9 124359700',
#  '#chromsize: 10 130530862',
#  '#chromsize: 11 121973369',
#  '#chromsize: 12 120092757',
#  '#chromsize: 13 120883175',
#  '#chromsize: 14 125139656',
#  '#chromsize: 15 104073951',
#  '#chromsize: 16 98008968',
#  '#chromsize: 17 95294699',
#  '#chromsize: 18 90720763',
#  '#chromsize: 19 61420004',
#  '#chromsize: X 169476592',
#  '#chromsize: Y 91455967',
#  '#chromsize: MT 16299',
#  '#chromsize: JH584299.1 953012',
#  '#chromsize: GL456233.2 559103',
#  '#chromsize: JH584301.1 259875',
#  '#chromsize: GL456211.1 241735',
#  '#chromsize: GL456221.1 206961',
#  '#chromsize: JH584297.1 205776',
#  '#chromsize: JH584296.1 199368',
#  '#chromsize: GL456354.1 195993',
#  '#chromsize: JH584298.1 184189',
#  '#chromsize: JH584300.1 182347',
#  '#chromsize: GL456219.1 175968',
#  '#chromsize: GL456210.1 169725',
#  '#chromsize: JH584303.1 158099',
#  '#chromsize: JH584302.1 155838',
#  '#chromsize: GL456212.1 153618',
#  '#chromsize: JH584304.1 114452',
#  '#chromsize: GL456379.1 72385',
#  '#chromsize: GL456366.1 47073',
#  '#chromsize: GL456367.1 42057',
#  '#chromsize: GL456239.1 40056',
#  '#chromsize: GL456383.1 38659',
#  '#chromsize: GL456385.1 35240',
#  '#chromsize: GL456360.1 31704',
#  '#chromsize: GL456378.1 31602',
#  '#chromsize: MU069435.1 31129',
#  '#chromsize: GL456389.1 28772',
#  '#chromsize: GL456372.1 28664',
#  '#chromsize: GL456370.1 26764',
#  '#chromsize: GL456381.1 25871',
#  '#chromsize: GL456387.1 24685',
#  '#chromsize: GL456390.1 24668',
#  '#chromsize: GL456394.1 24323',
#  '#chromsize: GL456392.1 23629',
#  '#chromsize: GL456382.1 23158',
#  '#chromsize: GL456359.1 22974',
#  '#chromsize: GL456396.1 21240',
#  '#chromsize: GL456368.1 20208',
#  '#chromsize: MU069434.1 8412',
#  '#chromsize: JH584295.1 1976',
#  '#samheader: @HD\tVN:1.6\tSO:unsorted\tGO:query',
#  '#samheader: @SQ\tSN:1\tLN:195154279',
#  '#samheader: @SQ\tSN:2\tLN:181755017',
#  '#samheader: @SQ\tSN:3\tLN:159745316',
#  '#samheader: @SQ\tSN:4\tLN:156860686',
#  '#samheader: @SQ\tSN:5\tLN:151758149',
#  '#samheader: @SQ\tSN:6\tLN:149588044',
#  '#samheader: @SQ\tSN:7\tLN:144995196',
#  '#samheader: @SQ\tSN:8\tLN:130127694',
#  '#samheader: @SQ\tSN:9\tLN:124359700',
#  '#samheader: @SQ\tSN:10\tLN:130530862',
#  '#samheader: @SQ\tSN:11\tLN:121973369',
#  '#samheader: @SQ\tSN:12\tLN:120092757',
#  '#samheader: @SQ\tSN:13\tLN:120883175',
#  '#samheader: @SQ\tSN:14\tLN:125139656',
#  '#samheader: @SQ\tSN:15\tLN:104073951',
#  '#samheader: @SQ\tSN:16\tLN:98008968',
#  '#samheader: @SQ\tSN:17\tLN:95294699',
#  '#samheader: @SQ\tSN:18\tLN:90720763',
#  '#samheader: @SQ\tSN:19\tLN:61420004',
#  '#samheader: @SQ\tSN:X\tLN:169476592',
#  '#samheader: @SQ\tSN:Y\tLN:91455967',
#  '#samheader: @SQ\tSN:MT\tLN:16299',
#  '#samheader: @SQ\tSN:JH584299.1\tLN:953012',
#  '#samheader: @SQ\tSN:GL456233.2\tLN:559103',
#  '#samheader: @SQ\tSN:JH584301.1\tLN:259875',
#  '#samheader: @SQ\tSN:GL456211.1\tLN:241735',
#  '#samheader: @SQ\tSN:GL456221.1\tLN:206961',
#  '#samheader: @SQ\tSN:JH584297.1\tLN:205776',
#  '#samheader: @SQ\tSN:JH584296.1\tLN:199368',
#  '#samheader: @SQ\tSN:GL456354.1\tLN:195993',
#  '#samheader: @SQ\tSN:JH584298.1\tLN:184189',
#  '#samheader: @SQ\tSN:JH584300.1\tLN:182347',
#  '#samheader: @SQ\tSN:GL456219.1\tLN:175968',
#  '#samheader: @SQ\tSN:GL456210.1\tLN:169725',
#  '#samheader: @SQ\tSN:JH584303.1\tLN:158099',
#  '#samheader: @SQ\tSN:JH584302.1\tLN:155838',
#  '#samheader: @SQ\tSN:GL456212.1\tLN:153618',
#  '#samheader: @SQ\tSN:JH584304.1\tLN:114452',
#  '#samheader: @SQ\tSN:GL456379.1\tLN:72385',
#  '#samheader: @SQ\tSN:GL456366.1\tLN:47073',
#  '#samheader: @SQ\tSN:GL456367.1\tLN:42057',
#  '#samheader: @SQ\tSN:GL456239.1\tLN:40056',
#  '#samheader: @SQ\tSN:GL456383.1\tLN:38659',
#  '#samheader: @SQ\tSN:GL456385.1\tLN:35240',
#  '#samheader: @SQ\tSN:GL456360.1\tLN:31704',
#  '#samheader: @SQ\tSN:GL456378.1\tLN:31602',
#  '#samheader: @SQ\tSN:MU069435.1\tLN:31129',
#  '#samheader: @SQ\tSN:GL456389.1\tLN:28772',
#  '#samheader: @SQ\tSN:GL456372.1\tLN:28664',
#  '#samheader: @SQ\tSN:GL456370.1\tLN:26764',
#  '#samheader: @SQ\tSN:GL456381.1\tLN:25871',
#  '#samheader: @SQ\tSN:GL456387.1\tLN:24685',
#  '#samheader: @SQ\tSN:GL456390.1\tLN:24668',
#  '#samheader: @SQ\tSN:GL456394.1\tLN:24323',
#  '#samheader: @SQ\tSN:GL456392.1\tLN:23629',
#  '#samheader: @SQ\tSN:GL456382.1\tLN:23158',
#  '#samheader: @SQ\tSN:GL456359.1\tLN:22974',
#  '#samheader: @SQ\tSN:GL456396.1\tLN:21240',
#  '#samheader: @SQ\tSN:GL456368.1\tLN:20208',
#  '#samheader: @SQ\tSN:MU069434.1\tLN:8412',
#  '#samheader: @SQ\tSN:JH584295.1\tLN:1976',
#  '#samheader: @PG\tPN:minimap2\tID:minimap2\tVN:2.28-r1209\tCL:minimap2 -ay -t 8 -x map-ont /scratch/indikar_root/indikar1/shared_data/single_cell/references/GRCm39.fa -',
#  '#samheader: @PG\tPN:pore-c-py\tID:pore-c-py-2\tVN:2.1.2\tPP:minimap2\tCL:/home/cstansbu/miniconda3/envs/pore_c/bin/pore-c-py annotate /scratch/indikar_root/indikar1/shared_data/single_cell/digest/o1b05.GRCm39.bam /scratch/indikar_root/indikar1/shared_data/single_cell/expanded/annotate/o1b05.GRCm39 --force --paired_end --monomers --summary --stdout --threads 8',
#  '#samheader: @PG\tID:pairtools_parse2\tPN:pairtools_parse2\tCL:/home/cstansbu/miniconda3/envs/pairtools/bin/pairtools parse2 --output-stats /scratch/indikar_root/indikar1/shared_data/single_cell/reports/pairtools/expanded/o1b05.GRCm39.stats.txt --chroms-path /scratch/indikar_root/indikar1/shared_data/single_cell/references/GRCm39.chrom.sizes --drop-sam --drop-seq --expand --report-position junction --report-orientation read --readid-transform readID.split(":")[0] --add-columns mapq,read_len,algn_read_span,algn_ref_span,matched_bp /scratch/indikar_root/indikar1/shared_data/single_cell/expanded/annotate/o1b05.GRCm39.ns.bam\tPP:pore-c-py-2\tVN:1.0.3',
#  '#samheader: @PG\tID:pairtools_restrict\tPN:pairtools_restrict\tCL:/home/cstansbu/miniconda3/envs/pairtools/bin/pairtools restrict -f /scratch/indikar_root/indikar1/shared_data/single_cell/references/GRCm39.fragments.bed -o /scratch/indikar_root/indikar1/shared_data/single_cell/expanded/pairs/o1b05.GRCm39.expanded.pairs\tPP:pairtools_parse2\tVN:1.0.3',
#  '#columns: readID chrom1 pos1 chrom2 pos2 strand1 strand2 pair_type mapq1 mapq2 read_len1 read_len2 algn_read_span1 algn_read_span2 algn_ref_span1 algn_ref_span2 matched_bp1 matched_bp2 rfrag1 rfrag_start1 rfrag_end1 rfrag2 rfrag_start2 rfrag_end2']

# %%
'readID', 
'chrom1', 
'pos1',
'chrom2',
'pos2', 
'mapq1',
'mapq2', 
'rfrag1',
'rfrag2',
